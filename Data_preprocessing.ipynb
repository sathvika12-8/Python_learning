# %%
import numpy as np
import pandas as pd

# %%
#Machine learning
#example of messy data
data = {
    "Name" : ["Ram","Shyam","Ram","Sita",None,"Shyam","Shyam","Shyam","Ram"],
    "Age" : [25,np.nan,25,30,22,13,17,18,19],
    "City" : ["Mumbai","mumbai","Mumbai","Delhi","Delhi","Delhi","Delhi","Delhi","Delhi"]
}
df = pd.DataFrame(data)
df
# Out:
#     Name   Age    City
# 0    Ram  25.0  Mumbai
# 1  Shyam   NaN  mumbai
# 2    Ram  25.0  Mumbai
# 3   Sita  30.0   Delhi
# 4   None  22.0   Delhi
# 5  Shyam  13.0   Delhi
# 6  Shyam  17.0   Delhi
# 7  Shyam  18.0   Delhi
# 8    Ram  19.0   Delhi

# %%
#identify and fix these issues
#first few rows
print(df.head())
print('this is info()===============')

# Data info
print(df.info())
print('this is describe()===============')

# Data description
print(df.describe())
# Out:
#     Name   Age    City
# 0    Ram  25.0  Mumbai
# 1  Shyam   NaN  mumbai
# 2    Ram  25.0  Mumbai
# 3   Sita  30.0   Delhi
# 4   None  22.0   Delhi
# this is info()===============
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    8 non-null      object
#  1   Age     8 non-null      float64
#  2   City    9 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 348.0+ bytes
# None
# this is describe()===============
#             Age
# count   8.00000
# mean   21.12500
# std     5.43632
# min    13.00000
# 25%    17.75000
# 50%    20.50000
# 75%    25.00000
# max    30.00000

# %%
#check missing values
print(df.isnull())

#count missing values
df.isnull().sum()
# Out:
#     Name    Age   City
# 0  False  False  False
# 1  False   True  False
# 2  False  False  False
# 3  False  False  False
# 4   True  False  False
# 5  False  False  False
# 6  False  False  False
# 7  False  False  False
# 8  False  False  False
# Name    1
# Age     1
# City    0
# dtype: int64

# %%
# Drop rows with missing values
df_drop  = df.dropna()
df_drop
# Out:
#     Name   Age    City
# 0    Ram  25.0  Mumbai
# 2    Ram  25.0  Mumbai
# 3   Sita  30.0   Delhi
# 5  Shyam  13.0   Delhi
# 6  Shyam  17.0   Delhi
# 7  Shyam  18.0   Delhi
# 8    Ram  19.0   Delhi

# %%
#Filling missing values
df["Age"] = df["Age"].fillna(df["Age"].mean()) #targeting the column
df["Name"] = df["Name"].fillna(df["Name"].mode()[0])
df
# Out:
#     Name     Age    City
# 0    Ram  25.000  Mumbai
# 1  Shyam  21.125  mumbai
# 2    Ram  25.000  Mumbai
# 3   Sita  30.000   Delhi
# 4  Shyam  22.000   Delhi
# 5  Shyam  13.000   Delhi
# 6  Shyam  17.000   Delhi
# 7  Shyam  18.000   Delhi
# 8    Ram  19.000   Delhi

# %%
#Selecting multiple columns
df = pd.DataFrame({
    "Age" : [20,np.nan,25,30,20],
    "Salary" : [20000,25000,np.nan,40000,20000],
    "City" : ["Mumbai","Delhi","Pune","Mumbai","Mumbai"]
})
df
# Out:
#     Age   Salary    City
# 0  20.0  20000.0  Mumbai
# 1   NaN  25000.0   Delhi
# 2  25.0      NaN    Pune
# 3  30.0  40000.0  Mumbai
# 4  20.0  20000.0  Mumbai

# %%
#Fill multiple columns with mean
df[["Age","Salary"]] = df[["Age","Salary"]].fillna(df[["Age","Salary"]].mean())
df
# Out:
#      Age   Salary    City
# 0  20.00  20000.0  Mumbai
# 1  23.75  25000.0   Delhi
# 2  25.00  26250.0    Pune
# 3  30.00  40000.0  Mumbai
# 4  20.00  20000.0  Mumbai

# %%
#convert multiple columns to integer
df[["Age","Salary"]].astype(int)
df.dtypes
df
# Out:
#      Age   Salary    City
# 0  20.00  20000.0  Mumbai
# 1  23.75  25000.0   Delhi
# 2  25.00  26250.0    Pune
# 3  30.00  40000.0  Mumbai
# 4  20.00  20000.0  Mumbai

# %%
#Increase values by 10%

df[["Age","Salary"]] = df[["Age","Salary"]].apply(lambda x: x*1.1)
df
# Out:
#       Age   Salary    City
# 0  22.000  22000.0  Mumbai
# 1  26.125  27500.0   Delhi
# 2  27.500  28875.0    Pune
# 3  33.000  44000.0  Mumbai
# 4  22.000  22000.0  Mumbai

# %%
#Replace specific values

df[["City"]] = df[["City"]].replace("Mumbai","MUMBAI")
df
# Out:
#       Age   Salary    City
# 0  22.000  22000.0  MUMBAI
# 1  26.125  27500.0   Delhi
# 2  27.500  28875.0    Pune
# 3  33.000  44000.0  MUMBAI
# 4  22.000  22000.0  MUMBAI

# %%
#Encoding(Categorical Numberical)
df_encoded = pd.get_dummies(df, columns=["City"])
df_encoded
# Out:
#       Age   Salary  City_Delhi  City_MUMBAI  City_Pune
# 0  22.000  22000.0       False         True      False
# 1  26.125  27500.0        True        False      False
# 2  27.500  28875.0       False        False       True
# 3  33.000  44000.0       False         True      False
# 4  22.000  22000.0       False         True      False

# %%
#Label Encoding
df_no_dup = df.drop_duplicates()
df_no_dup
# Out:
#       Age   Salary    City
# 0  22.000  22000.0  MUMBAI
# 1  26.125  27500.0   Delhi
# 2  27.500  28875.0    Pune
# 3  33.000  44000.0  MUMBAI

# %%
#convert all city names to lowercase
df["City"] = df["City"].str.lower()
df2=df.dropna()
df2
# Out:
#       Age   Salary    City
# 0  22.000  22000.0  mumbai
# 1  26.125  27500.0   delhi
# 2  27.500  28875.0    pune
# 3  33.000  44000.0  mumbai
# 4  22.000  22000.0  mumbai

# %%
df2.dropna()
df2["Age"]=df["Age"].astype(int)
print(df2)
df2.drop_duplicates()
# Out:
#    Age   Salary    City
# 0   22  22000.0  mumbai
# 1   26  27500.0   delhi
# 2   27  28875.0    pune
# 3   33  44000.0  mumbai
# 4   22  22000.0  mumbai
#    Age   Salary    City
# 0   22  22000.0  mumbai
# 1   26  27500.0   delhi
# 2   27  28875.0    pune
# 3   33  44000.0  mumbai
