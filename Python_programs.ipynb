# %%
#Arithmetic operators
a=10
b=13
print(a+b)
print(a-b)
print(a%b)
print(a/b)
print(a*b)
print(a//b)
# Out:
# 23
# -3
# 10
# 0.7692307692307693
# 130
# 0

# %%
#Assignment operators
a=10
a+=5
print(a)
a-=3
print(a)
a*=2
print(a)
a/=4
print(a)
a%=4
print(a)
# Out:
# 15
# 12
# 24
# 6.0
# 2.0

# %%
#Logical operators
a=True
b=False
print(a and b)
print(a or b)
print(not a)
print(not b)
# Out:
# False
# True
# False
# True

# %%
#Comparison  operators
a=10
b=20
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
#if condition
age=12
if age>=18:
    print("you are eligible for vote")
else:
    print("you are not eligible for vote")
# Out:
# you are not eligible for vote

# %%
#if-else condition
num=int(input("enter number"))
if(num%2==0):
  print("even number")
else:
  print("odd number")
# Out:
# enter number3
# odd number

# %%
#elif condition
marks=int(input("enter marks:"))
if(marks<=100 and marks>=90):
  print("grade A")
elif(marks<=89 and marks>=80):
  print("grade B")
elif(marks<=79 and marks>=70):
  print("grade C")
elif(marks<=69 and marks>=60):
  print("grade D")
else:
  print("fail")
# Out:
# enter marks:23
# fail

# %%
#nested if
age = int(input("Enter your age"))
citizen=True
if(citizen):
  if(age>=18):
    print("eligible")
  else:
    print("not eligible")
# Out:
# Enter your age23
# eligible

# %%
#for loop
for i in range(5):
  print(i)
for i in range(1,102,3):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 1
# 4
# 7
# 10
# 13
# 16
# 19
# 22
# 25
# 28
# 31
# 34
# 37
# 40
# 43
# 46
# 49
# 52
# 55
# 58
# 61
# 64
# 67
# 70
# 73
# 76
# 79
# 82
# 85
# 88
# 91
# 94
# 97
# 100

# %%
#while loop
num=100
while num>10:
  print(num)
  num+=1

# %%
#prime number
num = int(input("Enter number"))
count = 0
for i in range(1,num+1):
  if(num%i==0):
    count+=1
if(count==2):
  print("Number is prime number")
else:
  print("number is not prime number")

# %%
# factorial of a number
digit = int(input("enter number"))
fact = 1
for i in range(1,digit+1):
  fact = fact*i
print(fact)

# %%
s = "Programming"

reverse = ""

for i in s:
    reverse = i + reverse

print("Reversed String:", reverse)

# %%
string = "Hello"

count = 0

for char in string:
    if char in "aeiouAEIOU":
        count += 1

print("Number of vowels:", count)

# %%
s = input("Enter a string: ")

rev = ""
i = len(s) - 1

while i >= 0:
    rev += s[i]
    i -= 1

print("Reversed string:", rev)

# %%
#4 reverse of a number
num = 121
rev = 0
while num>0:
  remainder = num%10
  rev = rev*10 + remainder
  num = num//10
print("reverse",rev)

# %%
#Palindrome number
num=121
temp=num
rev=0
while num>0:
  remainder=num%10
  rev=rev*10+remainder
  num=num//10
if(temp==num):
  print("Palindrome number")
else:
  print("not Palindrome number")

# %%
#Armstrong number
num=153
sum=0
temp=sum
l=len(str(num))
for i in range(1+l):
  remainder=num%10
  sum=sum+remainder**l
  num=num//10
if(temp==sum):
  print("Armstrong number")
else:
  print("not Armstrong number")

# %%
#patterns
for i in range(0,6):
  for j in range(i+1):
    print("*",end=" ")
  print()

# %%
#reverse pattern
rows=5
for i in range(rows,0,-1):
  for j in range(0,i):
    print("*",end=" ")
  print()

# %%
#rectangle pattern
rows=4
cols=8
for i in range(rows):
  print("*" * cols)

# %%
#square pattern
side=5
for i in range(side):
  print("*" *side)

# %%
#circle pattern
radius=5
for y in range(-radius,radius+1):
  for x in range(-radius,radius+1):
    if x*x+y*y==radius*radius:
      print("*",end=" ")
    else:
      print(" ",end=" ")
  print()

# %%
#rhombus pattern
rows=5
for i in range(rows):
  print(""*(rows-1-i)+"*"*rows)

# %%
#Triangle pattern
rows=5
for i in range(1,rows+1):
  for j in range(1,i+1):
    print(j,end=" ")
  print()

# %%
#same number triangle pattern
rows=5
for i in range(1,rows+1):
  print((str(i)+" ")*i)

# %%
#floyd's triangle pattern
rows=5
num=1
for i in range(1,rows+1):
  for j in range(i):
    print(num,end=" ")
    num+=1
  print()

# %%
#star pyramid
rows=5
for i in range(rows):
  print(" "*(rows-i-1)+"*"*(2*i+1))

# %%
#inverted pyramid pattern
rows=5
for i in range(rows):
  print(" "*i+"*"*(2*(rows-i)-1))

# %%
#diamond pattern
rows=5
for i in range(rows):
  print(" "*(rows-i-1)+"*"*(2*i+1))
for j in range(rows-2,-1,-1):
  print(" "*(rows-i-1)+"*"*(2*i+1))

# %%
#alphabet triangle pattern
rows=5
for i in range(rows):
  for j in range(i+1):
    print(chr(65+j),end=" ")
  print()

# %%
#pascal's triangle pattern
nums=rows=5
for i in range(rows):
  nums=1
  print(" "*(rows-i)-1,end="")
for j in range(i+1):
  print(nums,end="")
  nums=nums*((i-j)//(i+j))
print()

# %%
#fibanocci
n=int(input("enter number of terms:"))
a=0
b=1
print("fibanocci series")
for i in range(n):
  print(a,end=" ")
  c=a+b
  a=b
  b=c

# %%
#largest number
a=int(input("enter first number:"))
b=int(input("enter second number:"))
c=int(input("enter third number:"))
if a>=b and a>=c:
  largest=a
elif b>=a and b>=c:
  largest=b
else:
  largest=c
print("largest number is:",largest)

# %%
#sum of digits
num=int(input("enter number:"))
sum_digits=0
while num>0:
  digit=num%10
  sum_digits+=digit
  num=num//10
print("sum of digits:",sum_digits)

# %%
#multiplication
num=int(input("Enter number:"))
for i in range(1,11):
  print(num, "x" , i , "=",num*i)

# %%
#write a program on simple linear prediction  given x, predict y using y=2x+3
x=int(input("enter value of x:"))
y=2*x+3
print("value of y is:",y)

# %%
#write a program on threshold classification if temperature>30 , it should print hot else normal take input print result
temp=float(input("enter temperature:"))
if temp>30:
  print("hot")
else:
  print("normal

# %%
#average of 5 numbers
n1=int(input("Enter first number"))
n2=int(input("Enter second number"))
n3=int(input("Enter third number"))
n4=int(input("Enter fourth number"))
n5=int(input("Enter fifth number"))
average = (n1+n2+n3+n4+n5)/5
print(average)

# %%
#datatypes
#list
colors=["yellow","blue","orange","green"]
colors.append("red")
print(colors)
colors.extend((["pink","white"]))
print(colors)
colors.insert(1,"violet")
print(colors)
colors.remove("blue")
print(colors)
colors.count("green")
print(colors)
colors.reverse()
print(colors)
colors.sort()
print(colors)
colors.pop(4)
print(colors)

# %%
#tuple
companies=("Amazon","CGI","walmart","microsoft")
print(companies.count("microsoft"))
print(companies.index(3))
print(len(companies))

# %%
#set
id1={3,4,5,6,4}
id2={2,4,6}
print(id1.union(id2))
print(id1.intersection(id2))
print(id1.difference(id2))
print(id1.add(12))
print(id2.remove(4))
print(id1.discard(5))
print(id1.pop())
print(id2.clear())

# %%
#dictionary
user={"name":"sathvika","age":20,"city":"hyderabad"}
print(user)
print(user.keys())
print(user.values())
print(user.items())
print(user.pop('age'))
print(user.update({'country':'india'}))
print(user.get('name'))
print(user.setdefault('state','telangana'))
print(user.popitem())

# %%
#string
text = " hello world 123 "

print("Original String:", text)

# Remove spaces
print("strip():", text.strip())

# Uppercase
print("upper():", text.upper())

# Lowercase
print("lower():", text.lower())

# Capitalize first letter
print("capitalize():", text.capitalize())

# Title case
print("title():", text.title())

# Replace word
print("replace():", text.replace("world", "Python"))

# Split string
print("split():", text.split())

# Join list into string
words = ["I", "love", "Python"]
print("join():", " ".join(words))

# Find character
print("find():", text.find("w"))

# Count occurrences
print("count():", text.count("l"))

# Startswith
print("startswith():", text.startswith(" "))

# Endswith
print("endswith():", text.endswith(" "))

# Check alphabet
print("isalpha():", text.isalpha())

# Check digit
num = "12345"
print("isdigit():", num.isdigit())

# Check alphanumeric
mix = "Python123"
print("isalnum():", mix.isalnum())

# Length of string
print("len():", len(text))

# Index of character
print("index():", text.index("h"))

# Swap uppercase and lowercase
mix2 = "PyThOn"
print("swapcase():", mix2.swapcase())

# %%
#append 100 to a list
num=[2,4,5,6]
num.append(100)
print(num)

# %%
#reverse a list
num=[2,5,6,8]
num.reverse()
print(num)

# %%
#minimum and maximum values in a list
num=[10,4,5,67,78]
print("minimum",min(num))
print("maximum",max(num))

# %%
#find sum of elements in a list
num=[10,20,40,50]
print("sum",sum(num))

# %%
#remove duplicates using set
num=[1,2,2,3,3,3,5]
unique=list(set(num))
print(unique)

# %%
#check if two lists have common elements
list1=[1,2,3,5]
list2=[1,4,5,6]
common=set(list1) & set(list2)
if common:
  print("common elements",common)
else:
  print("no common elements")

# %%
#count unique characters in string
s=input("enter string")
unique=len(set(s))
print("unique characters",unique)

# %%
#functions
def add(a,b):
  return a+b
result=add(10,20)
print(result)

# %%
#function with parameter and return value
def square(num):
  return num*num
result=square(4)
print(result)

# %%
#lambda
add=lambda a,b:a+b
print(add(2,5))

name=lambda name:print("hello",name)
name("sathvika")
n=lambda :"sathvika"
print(n())

# %%
#recursive
def factorial(n):
  if n==1:
    return 1
  else:
    return n*factorial(n-1)
result=factorial(5)
print(result)

# %%
#oop
class person:
  name="sathvika"
p=person()
q=person()
print(p.name)
print(q.name)

# %%
#emp
class emp:
  eid=101
  ename='sathvika'
obj=emp()
print(obj.eid)
print("the employee id is:",obj.eid,"and employee name is:",obj.ename)

# %%
#constructor
class student:
  def_init_(self,name,age):
    self.name=name
    self.age=age
s1=student("sathvika",20)
print("name:",self.name)
print("age:",self.age)

# %%
#method
class student:
  def_init_(self,name,age):
    self.name=name
    self.age=age
  def display(self):
    print("name:",self.name)
    print("age:",self.age)
s1=student("sathvika",20)
s1.display()

# %%
#create a class student wiht name,rollno, marks and add a method display student details
class student:
  def_init_(self,name,rollno,marks):
    self.name=name
    self.rollno=rollno
    self.marks=marks
  def display(self):
    print("name:",self.name)
    print("rollno:",self.rollno)
    print("marks:",self.marks)
s1=student("sathvika",101,90)
s1.display()

# %%
#create a class with a class name of rectangle with length and width,methods are area and perimeter
class Rectangle:
  def_init_(self,length,width):
    self.length=length
    self.width=width
  def area(self):
    return self.length*self.width
  def perimeter(self):
    return 2*(self.length+self.width)
r=Rectange(10,5)
print("area:",r.area())
print("perimeter:",r.perimeter())

# %%
#create a class with the class name of bank account with account number and balance along with methods are deposit,with draw,display balance
class BankAccount:
  def_init_(self,account_number,balance):
    self.account_number=account_number
    self.balance=balance
  def deposit(self,amount):
    self.balance+=amount
  def withdraw(self,amount):
    self.balance-=amount
  def display_balance(self):
    print("balance=",self.balance)
account=BankAccount("123456789",1000)
account.deposit(500)
account.withdraw(200)
account.display_balance()

# %%
#stack
class Stack:
    def __init__(self):
        self.items = []

    def push(self, data):
        self.items.append(data)

    def pop(self):
        return self.items.pop()

    def display(self):
        print("Stack:", self.items)


s = Stack()

s.push(10)
s.push(20)
s.push(30)

s.display()

print("Popped:", s.pop())

s.display()

# %%
#queue
class Queue:
    def __init__(self):
        self.items = []

    def enqueue(self, data):
        self.items.append(data)

    def dequeue(self):
        return self.items.pop(0)

    def display(self):
        print("Queue:", self.items)


q = Queue()

q.enqueue(10)
q.enqueue(20)
q.enqueue(30)

q.display()

print("Removed:", q.dequeue())

q.display()

# %%
#linkedlist
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


class LinkedList:
    def __init__(self):
        self.head = None

    def insert(self, data):
        new_node = Node(data)

        if self.head is None:
            self.head = new_node
        else:
            temp = self.head
            while temp.next:
                temp = temp.next
            temp.next = new_node

    def display(self):
        temp = self.head
        while temp:
            print(temp.data, end=" -> ")
            temp = temp.next


ll = LinkedList()

ll.insert(10)
ll.insert(20)
ll.insert(30)

ll.display()

# %%
#tree
class TreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None


class Tree:
    def __init__(self, root):
        self.root = TreeNode(root)

    def display(self):
        print("Root:", self.root.data)
        print("Left:", self.root.left.data)
        print("Right:", self.root.right.data)


t = Tree(10)

t.root.left = TreeNode(20)
t.root.right = TreeNode(30)

t.display()
